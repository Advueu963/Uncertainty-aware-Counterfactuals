# %%
from data import *
import matplotlib.pyplot as plt

# %%
def visualize_data(X,y):
    fig ,ax = plt.subplots(figsize=(6,6))
    ax.scatter(X[y == 0, 0], X[y == 0, 1],c="red", label="Class 0")
    ax.scatter(X[y == 1, 0], X[y == 1, 1],c="blue", label="Class 1")
    plt.legend()
    plt.show()

# %%
X,y,_ = load_bubbles()
visualize_data(X,y)

# %%
X,y,_ = load_one_moon()
visualize_data(X,y)

# %%
X,y,_ = load_ring_dataset()
visualize_data(X,y)

# %%
X,y,_ = load_two_moon()
visualize_data(X,y)

# %%
X,y,_ = load_bubbles_noisy()
visualize_data(X,y)

# %%
X,y,_ = load_l_dataset()
visualize_data(X,y)

# %%
X,y,_ = load_infinity_dataset()
visualize_data(X,y)

# %%
X,y,_ = load_bubbles_multiclass(1000)
plt.scatter(X[y == 0, 0], X[y == 0, 1], c="red", label="Class 0")
plt.scatter(X[y == 1, 0], X[y == 1, 1], c="blue", label="Class 1")
plt.scatter(X[y == 2, 0], X[y == 2, 1], c="green", label="Class 2")
plt.scatter(X[y == 3, 0], X[y == 3, 1], c="orange", label="Class 3")
plt.show()

# %%
X,y,_ = load_ring_dataset_multiclass(1000, noise=0)
plt.scatter(X[y == 0, 0], X[y == 0, 1], c="red", label="Class 0")
plt.scatter(X[y == 1, 0], X[y == 1, 1], c="blue", label="Class 1")
plt.scatter(X[y == 2, 0], X[y == 2, 1], c="green", label="Class 2")
plt.scatter(X[y == 3, 0], X[y == 3, 1], c="orange", label="Class 3")
plt.show()

# %%
X,y,_ = load_l_dataset_multiclass(500)
plt.scatter(X[y == 0, 0], X[y == 0, 1], c="red", label="Class 0")
plt.scatter(X[y == 1, 0], X[y == 1, 1], c="blue", label="Class 1")
plt.scatter(X[y == 2, 0], X[y == 2, 1], c="green", label="Class 2")
plt.scatter(X[y == 3, 0], X[y == 3, 1], c="orange", label="Class 3")
plt.show()

# %%
X,y,_ = load_four_moon(1000)
plt.scatter(X[y == 0, 0], X[y == 0, 1], c="red", label="Class 0")
plt.scatter(X[y == 1, 0], X[y == 1, 1], c="blue", label="Class 1")
plt.scatter(X[y == 2, 0], X[y == 2, 1], c="green", label="Class 2")
plt.scatter(X[y == 3, 0], X[y == 3, 1], c="orange", label="Class 3")
plt.show()
